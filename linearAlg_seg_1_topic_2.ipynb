# %% [markdown]
# <a href="https://colab.research.google.com/github/Mikkk1/Intro-to-Linear-Algebra-python/blob/main/linearAlg_seg_1_topic_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Tensors:**
#
# Machine Learning generalization of vertors and matrices to any no. of dimensions.
#
# ![Screenshot 2023-08-22 083819.png](data:image/png;base64,...)

# %% [markdown]
# ## **Scalers (Rank 0 tensors):**
#
#
#
# *   No Dimensions
# *   Single number
# *   Denoted in lower case, italics e.g. *'x'*

# %% [markdown]
# #### In Base Python:

# %%
x = 5
y = 10
x,y
# Out:
# (5, 10)

# %%
sum = x + y
sum
# Out:
# 15

# %% [markdown]
# #### Scalers in Python:

# %%
import tensorflow as tf

# %%
x_tf = tf.Variable(10, dtype = tf.int16)

# %%
x_tf
# Out:
# <tf.Variable 'Variable:0' shape=() dtype=int16, numpy=10>

# %%
y_tf = tf.Variable(15, dtype = tf.int16)

# %%
y_tf
# Out:
# <tf.Variable 'Variable:0' shape=() dtype=int16, numpy=15>

# %%
x_tf + y_tf
# Out:
# <tf.Tensor: shape=(), dtype=int16, numpy=25>

# %%
tf_sum = tf.add(x_tf, y_tf)

# %%
tf_sum
# Out:
# <tf.Tensor: shape=(), dtype=int16, numpy=25>

# %%
x_tf.shape
# Out:
# TensorShape([])

# %%
tf_sum.shape
# Out:
# TensorShape([])

# %%
type(tf_sum)
# Out:
# tensorflow.python.framework.ops.EagerTensor

# %% [markdown]
# We can convert these tensors to Numpy arrays:

# %%
tf_sum.numpy()
# Out:
# 25

# %%
type(tf_sum.numpy())
# Out:
# numpy.int16

# %% [markdown]
# We can also create tensors of other types:

# %%
z_tf = tf.Variable(7, dtype = tf.float16)

# %%
z_tfz
# Out:
# <tf.Variable 'Variable:0' shape=() dtype=float16, numpy=7.0>
